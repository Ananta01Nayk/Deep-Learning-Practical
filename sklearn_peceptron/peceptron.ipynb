# %% [markdown]
# ## perceptron in gradient descent

# %%
from sklearn.datasets import make_classification # Changed 'make_clasification' to 'make_classification'
import numpy as np

# %%
x ,y = make_classification(n_samples=100,n_features=20,n_informative=15,n_redundant=5)

# %%
# !pip install matplotlib-inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img_path = '/content/drive/MyDrive/perceptron.png'
img = mpimg.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.show()

# %%
image2_path ='/content/drive/MyDrive/peceptron_.png'
image2 =mpimg.imread(image2_path)
plt.imshow(image2)
plt.axis('off')
plt.show()

# %%
def peceptron(x,y):
  w1=w2=b=1
  lr=0.1
  for j in range(1000):
    for i in range(x.shape[0]):
      z = w1*x[i][0] + w2*x[i][1]+b
      if z<0:
        w1 = w1 + lr *y[i] *x[i][0]
        w2 = w2 + lr *y[i] * x[i][1]
        b = b + lr * y[i]
  return w1,w2,b

# %%
w1,w2,b=peceptron(x,y)

# %%
m = -(w1/w2)
c=-(w1/w2)
print(m,c)
# Out:
# 0.8432840417807376 0.8432840417807376

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input +c
plt.figure(figsize=(10,10))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1], c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
