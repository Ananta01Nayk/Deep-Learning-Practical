# %%
#import nessary library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#make temporery data
df = {
    "IQ": [4,5,6,7,8,9,1,4,5,6],
    "CGPA":[9,7,8,5.6,3.5,6,7,8,5,10],
    "PLACE":[1,1,1,0,0,1,0,1,0,1]
}

# %%
#show the data
data = pd.DataFrame(df)
print(data)
# Out:
#    IQ  CGPA  PLACE
# 0   4   9.0      1
# 1   5   7.0      1
# 2   6   8.0      1
# 3   7   5.6      0
# 4   8   3.5      0
# 5   9   6.0      1
# 6   1   7.0      0
# 7   4   8.0      1
# 8   5   5.0      0
# 9   6  10.0      1

# %%
#scater ploot for the input points
plt.scatter(data['CGPA'],data['IQ'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.title('scatter plot of iq and cgpa')
# Out:
# Text(0.5, 1.0, 'scatter plot of iq and cgpa')

# %%
#extract input variable and output variable
x=data.iloc[:,0:2]
y=data.iloc[:,-1]

# %%
print(x)
# Out:
#    IQ  CGPA
# 0   4   9.0
# 1   5   7.0
# 2   6   8.0
# 3   7   5.6
# 4   8   3.5
# 5   9   6.0
# 6   1   7.0
# 7   4   8.0
# 8   5   5.0
# 9   6  10.0

# %%
print(y)
# Out:
# 0    1
# 1    1
# 2    1
# 3    0
# 4    0
# 5    1
# 6    0
# 7    1
# 8    0
# 9    1
# Name: PLACE, dtype: int64

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[-5. ,  5.1]])

# %%
p.intercept_
# Out:
# array([-11.])

# %%
# here line is 
#y = x.(-5) + x1.(5.1) +(-11)

# %%
plt.scatter(data['CGPA'],data['IQ'])

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Extract x and x1 as Series
x = data['IQ']
x1 = data['CGPA']

# Compute y using the given equation
y = 5 * x + 5.1 * x1 - 11

# Create a 3D figure
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Scatter plot of x, x1, and y
ax.scatter(x, x1, y, color='blue', alpha=0.6, label="Data Points")

# Plot the equation surface
ax.plot_surface(X, X1, Y, color='red', alpha=0.5, edgecolor='black')

# Labels and title
ax.set_xlabel("x")
ax.set_ylabel("x1")
ax.set_zlabel("y")
ax.set_title("3D Scatter Plot with Equation Plane")
ax.legend()

plt.show()
